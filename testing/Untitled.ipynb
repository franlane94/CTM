# %%
import numpy as np
import matplotlib.pyplot as plt
from GCTM.gctm import GCTM

# %%
k_vals = np.logspace(-3,1,1000)

# %%
P_bz = GCTM().gctm_power(input_k=k_vals, z_val=0.0, kc=4.0)
# Out:
# Calculated the input power spectrum
# Calculated time dependent functions A(z) and B(z)
# Calculated the covariances
# Calculating the power spectrum:
# [========= ] 99%
# Time taken to calculate the power spectrum: 7.5784 minutes

# %%
P_lin=GCTM().linear_power(k_vals, z_val=0.0)

# %%
plt.loglog(k_vals,P_bz)
plt.loglog(k_vals,P_lin)
plt.xlim([1e-3, 5])
plt.ylim([1e-9,1e10])
# Out:
# (1e-09, 10000000000.0)

# %%
P_bz_0 = np.loadtxt("/Users/francescalane/my_phd/general_cosmological_trajectories_method/gctm_paper_1/undamped_bz_runs/P_bz_1_0.txt")

# %%
plt.loglog(k_vals,P_bz)
plt.loglog(k_vals,P_lin)
plt.loglog(k_vals, P_bz_0)
plt.xlim([1e-3,1])
plt.ylim([1e-9,1e5])
# Out:
# (1e-09, 100000.0)
